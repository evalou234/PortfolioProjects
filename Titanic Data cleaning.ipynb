# %%
#Import libraries
import numpy as np
import pandas as pd 
import seaborn as sns

#import matplotlib
#import matplotlib.pyplot as plt
#plt.style.use('ggplot')
#from matplotlib.pyplot import figure 

#%matplotlib inline 
#matplotlib.rcParams['figure.figsize']=(12,8) # adjusts the configuration of plots we will create

#read the data
df=pd.read_csv(r"C:\Users\Eva Njecacal\Downloads\PorfolioProject\titanic3.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   float64
#  1   survived   1309 non-null   float64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   float64
#  6   parch      1309 non-null   float64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 143.4+ KB

# %%
df['embarked'] = df['embarked'].replace(['S'], 'Southampton')
df['embarked'] = df['embarked'].replace(['C'], 'Cherbourg')
df['embarked'] = df['embarked'].replace(['Q'], 'Queenstown')

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     NaN       NaN                                              NaN
#
#          sex      age  sibsp  parch  ticket      fare    cabin     embarked  \
# ...

# %%
df1=(df['survived'][df['sex']=='female']).value_counts()
df1
# Out:
# survived
# 1.0    339
# 0.0    127
# Name: count, dtype: int64

# %%
df2=(df['survived'][df['sex']=='male']).value_counts()
df2
# Out:
# survived
# 0.0    682
# 1.0    161
# Name: count, dtype: int64

# %%
#What is the % of men and women who survived
print(df['sex'].value_counts())
print('% of male who survived', 100*np.mean(df['survived'][df['sex']=='male']))# %m= df2/tm*100
print('% of female who survived', 100*np.mean(df['survived'][df['sex']=='female']))# %f= df2/tf*100
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64
# % of male who survived 19.098457888493474
# % of female who survived 72.74678111587983

# %%
print(df['pclass'].value_counts())
print('% of passengers who survived in first class', 100*np.mean(df['survived'][df['pclass'] == 1]))
print('% of passengers who survived in second class', 100*np.mean(df['survived'][df['pclass'] == 2]))
print('% of passengers who survived in third class', 100*np.mean(df['survived'][df['pclass'] == 3]))
print(df[["pclass", "survived"]].groupby(['pclass']).mean())
# Out:
# pclass
# 3.0    709
# 1.0    323
# 2.0    277
# Name: count, dtype: int64
# % of passengers who survived in first class 61.91950464396285
# % of passengers who survived in second class 42.96028880866426
# % of passengers who survived in third class 25.52891396332863
#         survived
# pclass
# 1.0     0.619195
# 2.0     0.429603
# 3.0     0.255289

# %%
df1 = df.copy() #dataframe copy

df1.isnull().sum()
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age           264
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
df1['age'] = df1['age'].fillna(np.mean(df1['age']))
df1.isnull().sum()
#all null values of Age column replace with the mean of the column
# Out:
# pclass          1
# survived        1
# name            1
# sex             1
# age             0
# sibsp           1
# parch           1
# ticket          1
# fare            2
# cabin        1015
# embarked        3
# boat          824
# body         1189
# home.dest     565
# dtype: int64

# %%
# replace NAN Values(float)
df1['pclass'].fillna(df1['pclass'].mode()[0], inplace=True)
df1.isnull().sum()
df1['survived'].fillna(df1['survived'].mode()[0], inplace=True)
df1.isnull().sum()
df1['sibsp'].fillna(df1['sibsp'].mode()[0], inplace=True)
df1.isnull().sum()
df1['parch'].fillna(df1['parch'].mode()[0], inplace=True)
df1.isnull().sum()
df1['ticket'].fillna(df1['ticket'].mode()[0], inplace=True)
df1.isnull().sum()
df1['fare'].fillna(df1['fare'].mode()[0], inplace=True)
df1.isnull().sum()
df1['boat'].fillna(df1['boat'].mode()[0], inplace=True)
df1.isnull().sum()
df1['body'].fillna(df1['body'].mode()[0], inplace=True)
df1.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            1
# sex             1
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin        1015
# embarked        3
# boat            0
# body            0
# home.dest     565
# dtype: int64

# %%
#replace NA Values(object)
df1['name'].value_counts()
df1['name'].mode()
df1['name'].fillna(df1['name'].mode()[0], inplace=True)

df1['sex'].value_counts()
df1['sex'].mode()
df1['sex'].fillna(df1['sex'].mode()[0], inplace=True)


df1['embarked'].value_counts()
df1['embarked'].mode()
df1['embarked'].fillna(df1['embarked'].mode()[0], inplace=True)


df1['cabin'].value_counts()
df1['cabin'].mode()
df1['cabin'].fillna(df1['cabin'].mode()[0], inplace=True)

df1['home.dest'].value_counts()
df1['home.dest'].mode()
df1['home.dest'].fillna(df1['home.dest'].mode()[0], inplace=True)
df1.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# boat         0
# body         0
# home.dest    0
# dtype: int64

# %%
df1.head(11)
# Out:
#     pclass  survived                                             name     sex  \
# 0      1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1      1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2      1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3      1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4      1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5      1.0       1.0                              Anderson, Mr. Harry    male
# 6      1.0       1.0                Andrews, Miss. Kornelia Theodosia  female
# 7      1.0       0.0                           Andrews, Mr. Thomas Jr    male
# 8      1.0       1.0    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9      1.0       0.0                          Artagaveytia, Mr. Ramon    male
# 10     1.0       0.0                           Astor, Col. John Jacob    male
#
# ...

# %%
# divide home.dest in to two
df1[['home.dest','Adress']] = df1['home.dest'].str.split(' \/',n=1,expand=True)

# %%
df1
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     3.0       0.0                             Connolly, Miss. Kate
#
#          sex        age  sibsp  parch    ticket      fare        cabin  \
# ...

# %%
df1.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age             0
# sibsp           0
# parch           0
# ticket          0
# fare            0
# cabin           0
# embarked        0
# boat            0
# body            0
# home.dest       0
# Adress       1139
# dtype: int64

# %%
df= df1.drop(columns=['Adress'])

# %%
df
# Out:
#       pclass  survived                                             name  \
# 0        1.0       1.0                    Allen, Miss. Elisabeth Walton
# 1        1.0       1.0                   Allison, Master. Hudson Trevor
# 2        1.0       0.0                     Allison, Miss. Helen Loraine
# 3        1.0       0.0             Allison, Mr. Hudson Joshua Creighton
# 4        1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1305     3.0       0.0                            Zabour, Miss. Thamine
# 1306     3.0       0.0                        Zakarian, Mr. Mapriededer
# 1307     3.0       0.0                              Zakarian, Mr. Ortin
# 1308     3.0       0.0                               Zimmerman, Mr. Leo
# 1309     3.0       0.0                             Connolly, Miss. Kate
#
#          sex        age  sibsp  parch    ticket      fare        cabin  \
# ...

# %%
df.isnull().sum()
# Out:
# pclass       0
# survived     0
# name         0
# sex          0
# age          0
# sibsp        0
# parch        0
# ticket       0
# fare         0
# cabin        0
# embarked     0
# boat         0
# body         0
# home.dest    0
# dtype: int64

# %%
df= df.rename(columns={'home.dest': 'Adress', 'pclass': 'Passenger Class', 'sibsp': 'Siblings/Spouses Aboard','parch':'Parents/Children Aboard','ticket':'Ticket Number'})

# %%
df.head()
# Out:
#    Passenger Class  survived                                             name  \
# 0                1         1                    Allen, Miss. Elisabeth Walton
# 1                1         1                   Allison, Master. Hudson Trevor
# 2                1         0                     Allison, Miss. Helen Loraine
# 3                1         0             Allison, Mr. Hudson Joshua Creighton
# 4                1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex  age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0  female   29                        0                        0
# 1    male    0                        1                        2
# 2  female    2                        1                        2
# 3    male   30                        1                        2
# 4  female   25                        1                        2
#
#   Ticket Number      fare    cabin     embarked boat  body        Adress
# ...

# %%
df['age']=df['age'].astype('int64')
df['Passenger Class']=df['Passenger Class'].astype('int64')
df['Siblings/Spouses Aboard']=df['Siblings/Spouses Aboard'].astype('int64')
df['body']=df['body'].astype('int64')
df['survived']=df['survived'].astype('int64')
df['Parents/Children Aboard']=df['Parents/Children Aboard'].astype('int64')

# %%
df
# Out:
#       Passenger Class  survived  \
# 0                   1         1
# 1                   1         1
# 2                   1         0
# 3                   1         0
# 4                   1         0
# ...               ...       ...
# 1305                3         0
# 1306                3         0
# 1307                3         0
# 1308                3         0
# 1309                3         0
#
#                                                  name     sex  age  \
# 0                       Allen, Miss. Elisabeth Walton  female   29
# 1                      Allison, Master. Hudson Trevor    male    0
# 2                        Allison, Miss. Helen Loraine  female    2
# 3                Allison, Mr. Hudson Joshua Creighton    male   30
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female   25
# ...                                               ...     ...  ...
# 1305                            Zabour, Miss. Thamine  female   29
# ...
